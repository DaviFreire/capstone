# %%
import sys
import pandas as pd
import numpy as np
import csv
import os
import yahoo_finance_pynterface as yahoo
import matplotlib.pyplot        as plt
import matplotlib.dates         as mdates
import matplotlib.ticker        as mticker
from IPython.display import clear_output
from agent import DDPG
from naive_agent import Naive
from task import Task

def get_prices(ticker, date):
    return yahoo.Get.Prices(ticker, period=date)

prices = get_prices('AAPL', ['2018-04-02','2019-04-01']) 

first = prices['2018-04-02']
state = first
prices = prices.iloc[1:,]
# Out:
# Using TensorFlow backend.

# %%
## Naive Learning

prices_naive = prices
size = len(prices_naive)
task = Task(state, '2018-04-02') 
agent = Naive(task) 
labels = ['episode', 'total_rewards']
results = {x : [] for x in labels}

os.remove("reward.txt")
with open('reward.txt', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    for i in range(1000):
        day = 0
        score = 0
        state = first
        for date in prices_naive.index:
            date = date.strftime('%Y-%m-%d')
            stock = prices_naive[date]
            action = agent.act(state) 
            next_state, reward, done = task.step(action,stock)
            agent.step(reward, done)
            state = next_state
            score =+ reward
            day += 1
            if day == size:
                to_write = [day] + [score]
                for ii in range(len(labels)):
                    results[labels[ii]].append(to_write[ii])
                writer.writerow(to_write)
                print(score, end='')
            
            
        sys.stdout.flush()
# Out:
# 389.54245879656486

# %%
## DDPG Learning


size = len(prices)
task = Task(state, '2018-04-02') 
agent = DDPG(task) 
labels = ['episode', 'total_rewards']
results = {x : [] for x in labels}

os.remove("reward.txt")
with open('reward.txt', 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    for i in range(1000):
        day = 0
        score = 0
        state = first
        for date in prices.index:
            date = date.strftime('%Y-%m-%d')
            stock = prices[date]
            action = agent.act(state) 
            next_state, reward, done = task.step(action,stock)
            agent.step(action, reward, next_state, done)
            state = next_state
            score =+ reward
            day += 1
            if day == size:
                to_write = [day] + [score]
                for ii in range(len(labels)):
                    results[labels[ii]].append(to_write[ii])
                writer.writerow(to_write)

                print(score)
            
            
        sys.stdout.flush()
# Out:
# WARNING:tensorflow:From C:\Users\davif\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\davif\Anaconda3\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# 53.09634522943305
# 23.156909948173595
# 15.502201804252964
# 12.913627447329675
# 12.542822887644537
# 13.323257427757563
# 14.131895478817214
# 13.310550050430486
# 12.968374527167217
# 12.976499670281031
# 12.07213472195799
# 11.962881575278688
# 12.013075785731152
# 12.166247327485909
# 11.763020745055224
# 12.527771601172734
# 12.732614065724025
# 13.0552125649744
# 12.701773398945418
# 13.339560913422767
# 13.439723982971666
# 12.679362023822717
# 12.527515994158646
# 9.988936980444057
# 7.6158319448575895
# 6.628891089190991
# 5.723555028707059
# 5.0548268302199375
# 4.4416097949638935
# 3.9762914110369096
# 3.58896198194624
# 3.3026480922913795
# 3.0710693201177803
# 2.8635725978319537
# 2.66524729697721
# 2.4817052755357496
# 2.3568867068504082
# 2.2222216040897727
# 2.1735150350325294
# 2.181701164104245
# 2.166776663034928
# 2.1869060008079875
# 2.194594386143526
# 2.2036232174017627
# 2.230814100477846
# 2.227330231735974
# 2.215279331033967
# 2.2259347518547035
# 2.21122505639998
# 2.217618417480915
# 2.1975853360035793
# 2.181309731667232
# 2.158881071389442
# 2.1551555748117104
# 2.139241531323031
# 2.1436077052653264
# 2.1237507006449574
# 2.136632502073131
# 2.143821743750362
# 2.1476156078712276
# 2.1477483458281754
# 2.139114379824786
